# %%
from src.functions import *

# %%
df = pd.read_csv('data/boxscore_twenty_years.csv')
df
# Out:
#        Unnamed: 0      boxscore   away_name away_abbr  away_score  \
# 0               0  200010310ATL   Charlotte       CHH         106
# 1               1  200010310CHI  Sacramento       SAC         100
# 2               2  200010310DAL   Milwaukee       MIL          93
# 3               3  200010310GSW     Phoenix       PHO          94
# 4               4  200010310HOU   Minnesota       MIN         106
# ...           ...           ...         ...       ...         ...
# 25669       25669  202010020LAL       Miami       MIA         114
# 25670       25670  202010040MIA   LA Lakers       LAL         104
# 25671       25671  202010060MIA   LA Lakers       LAL         102
# 25672       25672  202010090LAL       Miami       MIA         111
# 25673       25673  202010110MIA   LA Lakers       LAL         106
#
#           home_name home_abbr  home_score  winning_name winning_abbr  \
# 0           Atlanta       ATL          82     Charlotte          CHH
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'boxscore', 'away_name', 'away_abbr', 'away_score',
#        'home_name', 'home_abbr', 'home_score', 'winning_name', 'winning_abbr',
#        'losing_name', 'losing_abbr'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#            boxscore   away_name away_abbr  away_score     home_name home_abbr  \
# 0      200010310ATL   Charlotte       CHH         106       Atlanta       ATL
# 1      200010310CHI  Sacramento       SAC         100       Chicago       CHI
# 2      200010310DAL   Milwaukee       MIL          93        Dallas       DAL
# 3      200010310GSW     Phoenix       PHO          94  Golden State       GSW
# 4      200010310HOU   Minnesota       MIN         106       Houston       HOU
# ...             ...         ...       ...         ...           ...       ...
# 25669  202010020LAL       Miami       MIA         114     LA Lakers       LAL
# 25670  202010040MIA   LA Lakers       LAL         104         Miami       MIA
# 25671  202010060MIA   LA Lakers       LAL         102         Miami       MIA
# 25672  202010090LAL       Miami       MIA         111     LA Lakers       LAL
# 25673  202010110MIA   LA Lakers       LAL         106         Miami       MIA
#
# ...

# %%
df['total_score'] = df['away_score'] + df['home_score']
df
# Out:
#            boxscore   away_name away_abbr  away_score     home_name home_abbr  \
# 0      200010310ATL   Charlotte       CHH         106       Atlanta       ATL
# 1      200010310CHI  Sacramento       SAC         100       Chicago       CHI
# 2      200010310DAL   Milwaukee       MIL          93        Dallas       DAL
# 3      200010310GSW     Phoenix       PHO          94  Golden State       GSW
# 4      200010310HOU   Minnesota       MIN         106       Houston       HOU
# ...             ...         ...       ...         ...           ...       ...
# 25669  202010020LAL       Miami       MIA         114     LA Lakers       LAL
# 25670  202010040MIA   LA Lakers       LAL         104         Miami       MIA
# 25671  202010060MIA   LA Lakers       LAL         102         Miami       MIA
# 25672  202010090LAL       Miami       MIA         111     LA Lakers       LAL
# 25673  202010110MIA   LA Lakers       LAL         106         Miami       MIA
#
# ...

# %%
df['total_score'].plot(figsize=(28,28))
# Out:
# <AxesSubplot:>

# %%
game = Boxscore('202010110MIA')

# %%
game.dataframe
# Out:
#               away_assist_percentage  away_assists  away_block_percentage  \
# 202010110MIA                    53.5            23                    7.8
#
#               away_blocks  away_defensive_rating  \
# 202010110MIA            4                  101.0
#
#               away_defensive_rebound_percentage  away_defensive_rebounds  \
# 202010110MIA                               79.1                       34
#
#               away_effective_field_goal_percentage  away_field_goal_attempts  \
# 202010110MIA                                 0.545                        89
#
#               away_field_goal_percentage  ...  \
# 202010110MIA                       0.483  ...
#
#               home_two_point_field_goal_percentage  \
# 202010110MIA                                 0.786
#
#               home_two_point_field_goals  home_wins  \
# 202010110MIA                          11          2
#
#                                   location  losing_abbr  losing_name  pace  \
# ...
